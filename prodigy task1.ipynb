# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a default dataset
data = pd.DataFrame({
    'day': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'],
    'count': [23, 15, 30, 35, 45, 60, 40]
})

# Plotting the bar chart
plt.figure(figsize=(8, 6))
sns.barplot(data=data, x='day', y='count', palette='pastel')
plt.title('Distribution of Days in the Week', fontsize=16)
plt.xlabel('Day', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\mohan\AppData\Local\Temp\ipykernel_13176\1100736979.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x='day', y='count', palette='pastel')
